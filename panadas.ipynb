# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhithaaxreddy/NASSCOM/blob/main/panadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={"name":["A","B","C"],
"age":[20,18,22],
"marks":[10,20,30]}

# %%
df= pd.DataFrame(data)

# %%
print(df)
# Out:
#   name  age  marks
# 0    A   20     10
# 1    B   18     20
# 2    C   22     30

# %%
df["marks"]
# Out:
# 0    10
# 1    20
# 2    30
# Name: marks, dtype: int64

# %%
df.marks+5
# Out:
# 0    15
# 1    25
# 2    35
# Name: marks, dtype: int64

# %%
df.head()
# Out:
#   name  age  marks
# 0    A   20     10
# 1    B   18     20
# 2    C   22     30

# %%
df.shape
# Out:
# (3, 3)

# %%
df.dtypes
# Out:
# name     object
# age       int64
# marks     int64
# dtype: object

# %%
df=pd.read_csv("/content/Student_Performance.csv")

# %%
df.head()
# Out:
#     S.NO   Name   Roll NO    Branch  Hobby 1      Hobby 2             Place  \
# 0      1  Bhanu  25wh1a05       cse    dance          fun          nizampet
# 1      2  radha  25wh1a06       eee  singing      skating          rachapet
# 2      3   rani  25wh1a07        it  sliding     crafting              jntu
# 3      4    aju  25wh1a08       ece  writing  volley ball         rasulpura
# 4      5  kamal  25wh1a09  pharmacy  skating      cooking  paradaise circle
#
#    no.of siblings  Age  Marks
# 0               2   18     98
# 1               4   18     97
# 2               1   18     95
# 3               3   18     96
# 4               2   18     88

# %%
df.dtypes
# Out:
#  S.NO              int64
# Name              object
# Roll NO           object
# Branch            object
# Hobby 1           object
# Hobby 2           object
# Place             object
# no.of siblings     int64
# Age                int64
# Marks              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0    S.NO           25 non-null     int64
#  1   Name            25 non-null     object
#  2   Roll NO         25 non-null     object
#  3   Branch          25 non-null     object
#  4   Hobby 1         25 non-null     object
#  5   Hobby 2         25 non-null     object
#  6   Place           25 non-null     object
#  7   no.of siblings  25 non-null     int64
#  8   Age             25 non-null     int64
#  9   Marks           25 non-null     int64
# dtypes: int64(4), object(6)
# memory usage: 2.1+ KB

# %%
df["Marks"].median()
# Out:
# 87.0

# %%
df["Marks"].mean()
df["Marks"].std()
df["Marks"].min()
df["Marks"].max()
df["Marks"].quantile(0.25)
df["Marks"].quantile(0.50)
df["Marks"].quantile(0.75)
# Out:
# np.float64(90.0)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      S.NO       Name   Roll NO    Branch  Hobby 1      Hobby 2  \
# 0       1      Bhanu  25wh1a05       cse    dance          fun
# 1       2      radha  25wh1a06       eee  singing      skating
# 2       3       rani  25wh1a07        it  sliding     crafting
# 3       4        aju  25wh1a08       ece  writing  volley ball
# 4       5      kamal  25wh1a09  pharmacy  skating      cooking
# 5       6      kumal  25wh1a10      mech   coding       living
# 6       7      kunal  25wh1a11        au    dance          fun
# 7       8    ravider  25wh1a12       cse  singing      skating
# 8       9       mani  25wh1a13       eee  sliding     crafting
# 9      10    ravider  25wh1a14        it  writing  volley ball
# 10     11       minu  25wh1a15       ece  skating      cooking
# 11     12    muickey  25wh1a16  pharmacy   coding       living
# 12     13      kumar  25wh1a17      mech    dance          fun
# ...

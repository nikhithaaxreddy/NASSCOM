# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhithaaxreddy/NASSCOM/blob/main/TASKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1.1

# %%
import os
import random
from datetime import datetime, timedelta

# Sample data (Remove if already provided)
DEVICE_TYPES = [
    "Temperature_Sensor",
    "Humidity_Sensor",
    "Pressure_Sensor",
    "Light_Sensor"
]

LOCATIONS = [
    "Lab-A",
    "Lab-B",
    "Warehouse",
    "Office",
    "Factory"
]

READING_RANGES = {
    "Temperature_Sensor": (15.0, 40.0),
    "Humidity_Sensor": (20.0, 90.0),
    "Pressure_Sensor": (950.0, 1050.0),
    "Light_Sensor": (100.0, 1000.0)
}

raw_sensor_data = []

start_time = datetime.now()

for i in range(100):
    timestamp = (start_time + timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append((timestamp, device_id, device_type, location, value))

# %% [markdown]
# TASK 1.2

# %%
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

# %% [markdown]
# TASK 1.3

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

# %% [markdown]
# TASK 1.4

# %%
device_stats = {}

# Initialize dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find minimum and maximum values
for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    device_stats[device] = (
        min(current_min, value),
        max(current_max, value)
    )

# %% [markdown]
# TASK 1.5.1

# %%
# 10th to 20th readings (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading
sliced_readings_2 = raw_sensor_data[::5]

# %% [markdown]
# TASK 1.5.2

# %%
sample_string = "PythonProgrammingIsFun"

# Extract "Programming"
substring_1 = sample_string[6:17]

# Extract "nohtyP"
substring_2 = sample_string[5::-1]

# %% [markdown]
# TASK 1.5.3

# %%
sample_string = "PythonProgrammingIsFun"

# Extract "Programming"
substring_1 = sample_string[6:17]

# Extract "nohtyP"
substring_2 = sample_string[5::-1]

# %% [markdown]
# WHOLE TASK 1

# %%
import random
from datetime import datetime, timedelta

print("\n--- Task 1: Data Generation and Basic Structures ---")

# Example definitions (remove these if already provided)
DEVICE_TYPES = [
    "Temperature_Sensor",
    "Humidity_Sensor",
    "Pressure_Sensor",
    "Light_Sensor"
]

LOCATIONS = [
    "Lab-A",
    "Lab-B",
    "Warehouse",
    "Office",
    "Factory"
]

READING_RANGES = {
    "Temperature_Sensor": (15.0, 40.0),
    "Humidity_Sensor": (20.0, 90.0),
    "Pressure_Sensor": (950.0, 1050.0),
    "Light_Sensor": (100.0, 1000.0)
}

# 1.1 Generate raw_sensor_data
raw_sensor_data = []

start_time = datetime.now()

for i in range(100):
    timestamp = (start_time + timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

# --------------------------------------------------

# 1.2 Temperature readings list of dictionaries

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

# --------------------------------------------------

# 1.3 Unique locations

unique_locations = {reading[3] for reading in raw_sensor_data}

# --------------------------------------------------

# 1.4 Device statistics (min, max)

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update
for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    device_stats[device] = (
        min(current_min, value),
        max(current_max, value)
    )

print(device_stats)

# --------------------------------------------------

print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing

# 10th to 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading
sliced_readings_2 = raw_sensor_data[::5]

# --------------------------------------------------

# 1.5.2 String Slicing

substring_1 = sample_string[6:17]      # Programming
substring_2 = sample_string[5::-1]     # nohtyP

print(substring_1)
print(substring_2)

# --------------------------------------------------

# 1.5.3 Mixed Slicing

fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# {'Temperature_Sensor': (15.7, 39.09), 'Humidity_Sensor': (21.01, 89.11), 'Pressure_Sensor': (951.88, 1045.68), 'Light_Sensor': (107.54, 979.79)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Programming
# nohtyP
# Pressure_Sensor
# Sensor

# %% [markdown]
# TASK 2.1

# %%
def get_readings_by_location(readings_list, target_location):
    location_readings = []

    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings

# %% [markdown]
# TASK 2.2

# %%
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return average

# %% [markdown]
# TASK 2.3

# %%
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

# %% [markdown]
# WHOLE TASK 2

# %%
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

def get_readings_by_location(readings_list, target_location):
    location_readings = []

    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings


# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature.
#     Return 0.0 if the list is empty.

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return average


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


# ------------------ Example Usage ------------------

# Task 2.1
lab_readings = get_readings_by_location(raw_sensor_data, "Lab-A")
print("\nReadings from Lab-A:")
print(lab_readings)

# Task 2.2
average_temp = calculate_average_temperature(temperature_readings)
print("\nAverage Temperature:")
print(average_temp)

# Task 2.3
if temperature_readings:
    print("\nSample Report Line:")
    print(generate_report_line(temperature_readings[0]))
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Readings from Lab-A:
# [('2026-07-31 10:06:56', 'DEV005', 'Pressure_Sensor', 'Lab-A', 1032.25), ('2026-07-31 10:13:56', 'DEV012', 'Humidity_Sensor', 'Lab-A', 59.3), ('2026-07-31 10:17:56', 'DEV016', 'Pressure_Sensor', 'Lab-A', 983.99), ('2026-07-31 10:19:56', 'DEV018', 'Pressure_Sensor', 'Lab-A', 1032.01), ('2026-07-31 10:21:56', 'DEV020', 'Light_Sensor', 'Lab-A', 143.57), ('2026-07-31 10:22:56', 'DEV021', 'Humidity_Sensor', 'Lab-A', 88.44), ('2026-07-31 10:25:56', 'DEV024', 'Pressure_Sensor', 'Lab-A', 990.2), ('2026-07-31 10:29:56', 'DEV028', 'Light_Sensor', 'Lab-A', 107.54), ('2026-07-31 10:31:56', 'DEV030', 'Humidity_Sensor', 'Lab-A', 70.06), ('2026-07-31 10:36:56', 'DEV035', 'Temperature_Sensor', 'Lab-A', 19.25), ('2026-07-31 10:37:56', 'DEV036', 'Temperature_Sensor', 'Lab-A', 37.19), ('2026-07-31 10:40:56', 'DEV039', 'Humidity_Sensor', 'Lab-A', 40.24), ('2026-07-31 10:41:56', 'DEV040', 'Light_Sensor', 'Lab-A', 746.63), ('2026-07-31 10:52:56', 'DEV051', 'Light_Sensor', 'Lab-A', 252.51), ('2026-07-31 10:54:56', 'DEV053', 'Light_Sensor', 'Lab-A', 736.66), ('2026-07-31 11:07:56', 'DEV066', 'Pressure_Sensor', 'Lab-A', 965.73), ('2026-07-31 11:09:56', 'DEV068', 'Temperature_Sensor', 'Lab-A', 21.42), ('2026-07-31 11:11:56', 'DEV070', 'Humidity_Sensor', 'Lab-A', 59.31), ('2026-07-31 11:12:56', 'DEV071', 'Temperature_Sensor', 'Lab-A', 18.35), ('2026-07-31 11:23:56', 'DEV082', 'Humidity_Sensor', 'Lab-A', 57.52), ('2026-07-31 11:26:56', 'DEV085', 'Temperature_Sensor', 'Lab-A', 30.65), ('2026-07-31 11:39:56', 'DEV098', 'Temperature_Sensor', 'Lab-A', 34.97), ('2026-07-31 11:40:56', 'DEV099', 'Light_Sensor', 'Lab-A', 931.13)]
#
# Average Temperature:
# 26.832962962962963
#
# Sample Report Line:
# [2026-07-31 10:04:56] Device DEV003 at Lab-B: 26.63°C

# %% [markdown]
# TASK 3.1

# %%
reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %% [markdown]
# TASK 3.2

# %%
if len(raw_sensor_data) > 1:

    first_timestamp = raw_sensor_data[0][0]
    last_timestamp = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.strptime(first_timestamp, date_format)
    last_dt = datetime.strptime(last_timestamp, date_format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print("\nDuration of data collection:")
    print(f"{days} days, {hours} hours, {minutes} minutes")

else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection:
# 0 days, 1 hours, 39 minutes

# %% [markdown]
# TASK 3.3

# %%
random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [150, 168, 129, 172, 130]

# %% [markdown]
# WHOLE TASK 3

# %%
print("\n--- Task 3: Core Library Usage ---")

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")

if len(raw_sensor_data) > 1:
    first_timestamp = raw_sensor_data[0][0]
    last_timestamp = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.strptime(first_timestamp, date_format)
    last_dt = datetime.strptime(last_timestamp, date_format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# --- Task 3: Core Library Usage ---
# Directory 'sensor_reports' already exists.
#
# Duration of data collection: 0 days, 1 hours, 39 minutes.
#
# Random Values:
# [141, 172, 129, 130, 195]

# %% [markdown]
# TASK 4.1

# %%
report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as file:
        for reading in temperature_readings:
            file.write(generate_report_line(reading) + "\n")

    print(f"Temperature report written to '{report_filename}'.")
except IOError as e:
    print(f"Error writing file: {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %% [markdown]
# TASK 4.2

# %%
try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# First 3 lines of the report:
# [2026-07-31 10:04:56] Device DEV003 at Lab-B: 26.63°C
# [2026-07-31 10:05:56] Device DEV004 at Warehouse: 30.03°C
# [2026-07-31 10:07:56] Device DEV006 at Lab-B: 17.67°C

# %% [markdown]
# WHOLE TASK 4

# %%
print("\n--- Task 4: File I/O ---")

report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as file:
        for reading in temperature_readings:
            file.write(generate_report_line(reading) + "\n")

    print(f"Temperature report written to '{report_filename}'.")
except IOError as e:
    print(f"Error writing file: {e}")

try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file: {e}")

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Task 4: File I/O ---
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# First 3 lines of the report:
# [2026-07-31 10:04:56] Device DEV003 at Lab-B: 26.63°C
# [2026-07-31 10:05:56] Device DEV004 at Warehouse: 30.03°C
# [2026-07-31 10:07:56] Device DEV006 at Lab-B: 17.67°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.

# %% [markdown]
# COMPLETE TASK

# %%
import os
import random
from datetime import datetime, timedelta

print("\n--- Task 1: Data Generation and Basic Structures ---")

# Example definitions (remove these if already provided)
DEVICE_TYPES = [
    "Temperature_Sensor",
    "Humidity_Sensor",
    "Pressure_Sensor",
    "Light_Sensor"
]

LOCATIONS = [
    "Lab-A",
    "Lab-B",
    "Warehouse",
    "Office",
    "Factory"
]

READING_RANGES = {
    "Temperature_Sensor": (15.0, 40.0),
    "Humidity_Sensor": (20.0, 90.0),
    "Pressure_Sensor": (950.0, 1050.0),
    "Light_Sensor": (100.0, 1000.0)
}

# 1.1 Generate raw_sensor_data
raw_sensor_data = []

start_time = datetime.now()

for i in range(100):
    timestamp = (start_time + timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

# --------------------------------------------------

# 1.2 Temperature readings list of dictionaries

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

# --------------------------------------------------

# 1.3 Unique locations

unique_locations = {reading[3] for reading in raw_sensor_data}

# --------------------------------------------------

# 1.4 Device statistics (min, max)

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update
for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    device_stats[device] = (
        min(current_min, value),
        max(current_max, value)
    )

print(device_stats)

# --------------------------------------------------

print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing

# 10th to 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading
sliced_readings_2 = raw_sensor_data[::5]

# --------------------------------------------------

# 1.5.2 String Slicing

substring_1 = sample_string[6:17]      # Programming
substring_2 = sample_string[5::-1]     # nohtyP

print(substring_1)
print(substring_2)

# --------------------------------------------------

# 1.5.3 Mixed Slicing

fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)

print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

def get_readings_by_location(readings_list, target_location):
    location_readings = []

    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings


# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature.
#     Return 0.0 if the list is empty.

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return average


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


# ------------------ Example Usage ------------------

# Task 2.1
lab_readings = get_readings_by_location(raw_sensor_data, "Lab-A")
print("\nReadings from Lab-A:")
print(lab_readings)

# Task 2.2
average_temp = calculate_average_temperature(temperature_readings)
print("\nAverage Temperature:")
print(average_temp)

# Task 2.3
if temperature_readings:
    print("\nSample Report Line:")
    print(generate_report_line(temperature_readings[0]))




print("\n--- Task 3: Core Library Usage ---")

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")

if len(raw_sensor_data) > 1:
    first_timestamp = raw_sensor_data[0][0]
    last_timestamp = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.strptime(first_timestamp, date_format)
    last_dt = datetime.strptime(last_timestamp, date_format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)

print("\n--- Task 4: File I/O ---")

report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as file:
        for reading in temperature_readings:
            file.write(generate_report_line(reading) + "\n")

    print(f"Temperature report written to '{report_filename}'.")
except IOError as e:
    print(f"Error writing file: {e}")

try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file: {e}")

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# {'Temperature_Sensor': (16.43, 38.34), 'Humidity_Sensor': (20.89, 81.48), 'Pressure_Sensor': (953.29, 1048.83), 'Light_Sensor': (103.05, 961.36)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
#
# --- Task 2: Function Definitions and Usage ---
#
# Readings from Lab-A:
# [('2026-07-31 10:21:58', 'DEV003', 'Humidity_Sensor', 'Lab-A', 50.62), ('2026-07-31 10:25:58', 'DEV007', 'Temperature_Sensor', 'Lab-A', 29.1), ('2026-07-31 10:30:58', 'DEV012', 'Pressure_Sensor', 'Lab-A', 1009.26), ('2026-07-31 10:34:58', 'DEV016', 'Light_Sensor', 'Lab-A', 114.21), ('2026-07-31 10:37:58', 'DEV019', 'Humidity_Sensor', 'Lab-A', 52.93), ('2026-07-31 10:51:58', 'DEV033', 'Temperature_Sensor', 'Lab-A', 25.87), ('2026-07-31 10:52:58', 'DEV034', 'Pressure_Sensor', 'Lab-A', 982.44), ('2026-07-31 10:56:58', 'DEV038', 'Pressure_Sensor', 'Lab-A', 953.29), ('2026-07-31 10:59:58', 'DEV041', 'Light_Sensor', 'Lab-A', 870.16), ('2026-07-31 11:02:58', 'DEV044', 'Pressure_Sensor', 'Lab-A', 965.57), ('2026-07-31 11:05:58', 'DEV047', 'Humidity_Sensor', 'Lab-A', 30.11), ('2026-07-31 11:14:58', 'DEV056', 'Temperature_Sensor', 'Lab-A', 31.22), ('2026-07-31 11:22:58', 'DEV064', 'Humidity_Sensor', 'Lab-A', 74.29), ('2026-07-31 11:28:58', 'DEV070', 'Pressure_Sensor', 'Lab-A', 1047.9), ('2026-07-31 11:31:58', 'DEV073', 'Humidity_Sensor', 'Lab-A', 79.86), ('2026-07-31 11:47:58', 'DEV089', 'Pressure_Sensor', 'Lab-A', 981.35)]
#
# Average Temperature:
# 27.415238095238095
#
# Sample Report Line:
# [2026-07-31 10:24:58] Device DEV006 at Lab-B: 37.58°C
#
# --- Task 3: Core Library Usage ---
# Directory 'sensor_reports' already exists.
#
# Duration of data collection: 0 days, 1 hours, 39 minutes.
#
# Random Values:
# [162, 195, 132, 105, 175]
#
# --- Task 4: File I/O ---
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# First 3 lines of the report:
# [2026-07-31 10:24:58] Device DEV006 at Lab-B: 37.58°C
# [2026-07-31 10:25:58] Device DEV007 at Lab-A: 29.1°C
# [2026-07-31 10:36:58] Device DEV018 at Warehouse: 17.42°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
